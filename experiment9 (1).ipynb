# %%
class Student:
    def get_data(self):
        self.name = input("Enter Name: ")
        self.sap_id = input("Enter SAP ID: ")
        self.phy = int(input("Enter Physics Marks: "))
        self.chem = int(input("Enter Chemistry Marks: "))
        self.maths = int(input("Enter Maths Marks: "))

    def display(self):
        print("\nName:", self.name)
        print("SAP ID:", self.sap_id)
        print("Marks -> Phy:", self.phy, "Chem:", self.chem, "Maths:", self.maths)

# Create 3 objects
students = []
for i in range(3):
    print(f"\nEnter details of Student {i+1}")
    s = Student()
    s.get_data()
    students.append(s)

# Display
for s in students:
    s.display()
# Out:
# Enter details of Student 1
# Enter Name: mehak
# Enter SAP ID: 26050
# Enter Physics Marks: 70
# Enter Chemistry Marks: 56
# Enter Maths Marks: 45
#
# Enter details of Student 2
# Enter Name: pavni
# Enter SAP ID: 6797
# Enter Physics Marks: 67
# Enter Chemistry Marks: 56
# Enter Maths Marks: 78
#
# Enter details of Student 3
# Enter Name: avantika
# Enter SAP ID: 87873
# Enter Physics Marks: 98
# Enter Chemistry Marks: 87
# Enter Maths Marks: 78
#
# Name: mehak
# SAP ID: 26050
# Marks -> Phy: 70 Chem: 56 Maths: 45
#
# Name: pavni
# SAP ID: 6797
# Marks -> Phy: 67 Chem: 56 Maths: 78
#
# Name: avantika
# SAP ID: 87873
# Marks -> Phy: 98 Chem: 87 Maths: 78

# %%
class Student:
    def __init__(self, name, sap_id, phy, chem, maths):
        self.name = name
        self.sap_id = sap_id
        self.phy = phy
        self.chem = chem
        self.maths = maths

    def display(self):
        print(f"\nName: {self.name}, SAP ID: {self.sap_id}")
        print(f"Marks -> Phy:{self.phy}, Chem:{self.chem}, Maths:{self.maths}")

    def marks_percentage(self):
        total = self.phy + self.chem + self.maths
        return total / 3

    def result(self):
        if self.phy > 40 and self.chem > 40 and self.maths > 40:
            return "Pass"
        else:
            return "Fail"

# Input n students
n = int(input("Enter number of students: "))
students = []

for i in range(n):
    print(f"\nEnter details of Student {i+1}")
    name = input("Name: ")
    sap = input("SAP ID: ")
    phy = int(input("Physics: "))
    chem = int(input("Chemistry: "))
    maths = int(input("Maths: "))

    students.append(Student(name, sap, phy, chem, maths))

# Display + Result
for s in students:
    s.display()
    print("Percentage:", s.marks_percentage())
    print("Result:", s.result())

# Class average
def class_average(students):
    total = sum(s.marks_percentage() for s in students)
    return total / len(students)

print("\nClass Average:", class_average(students))
# Out:
# Enter number of students: 2
#
# Enter details of Student 1
# Name: tanisha
# SAP ID: 57890
# Physics: 89
# Chemistry: 78
# Maths: 37
#
# Enter details of Student 2
# Name: avantika
# SAP ID: 67849
# Physics: 89
# Chemistry: 46
# Maths: 67
#
# Name: tanisha, SAP ID: 57890
# Marks -> Phy:89, Chem:78, Maths:37
# Percentage: 68.0
# Result: Fail
#
# Name: avantika, SAP ID: 67849
# Marks -> Phy:89, Chem:46, Maths:67
# Percentage: 67.33333333333333
# Result: Pass
#
# Class Average: 67.66666666666666

# %%
# Single Inheritance
class Parent:
    def show(self):
        print("This is Parent class")

class Child(Parent):
    def display(self):
        print("This is Child class")

c = Child()
c.show()
c.display()

# Multilevel Inheritance
class Grandparent:
    def gp(self):
        print("Grandparent")

class Parent(Grandparent):
    def p(self):
        print("Parent")

class Child(Parent):
    def c(self):
        print("Child")

obj = Child()
obj.gp()
obj.p()
obj.c()

# Multiple Inheritance
class A:
    def showA(self):
        print("Class A")

class B:
    def showB(self):
        print("Class B")

class C(A, B):
    def showC(self):
        print("Class C")

obj = C()
obj.showA()
obj.showB()
obj.showC()
# Out:
# This is Parent class
# This is Child class
# Grandparent
# Parent
# Child
# Class A
# Class B
# Class C

# %%
class Parent:
    def show(self):
        print("This is Parent method")

class Child(Parent):
    def show(self):  # overriding
        print("This is Child method")

obj = Child()
obj.show()
# Out:
# This is Child method

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def display(self):
        print(f"Point({self.x}, {self.y})")

# Example
p1 = Point(10, 20)
p2 = Point(12, 15)

p3 = p1 + p2

p3.display()   # Output: Point(22, 35)
# Out:
# Point(22, 35)
